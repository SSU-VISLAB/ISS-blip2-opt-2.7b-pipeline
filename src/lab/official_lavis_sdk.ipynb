# %%
import sys
if 'google.colab' in sys.modules:
    print('Running in Colab.')
    # !pip3 install salesforce-lavis

# %%
import torch
from PIL import Image
import requests
from lavis.models import load_model_and_preprocess
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import torch
#       2 from PIL import Image
#       3 import requests
#
# ModuleNotFoundError: No module named 'torch'

# %%
img_url = 'https://storage.googleapis.com/sfr-vision-language-research/LAVIS/assets/merlion.png' 
raw_image = Image.open(requests.get(img_url, stream=True).raw).convert('RGB')   
display(raw_image.resize((596, 437)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 img_url = 'https://storage.googleapis.com/sfr-vision-language-research/LAVIS/assets/merlion.png'
# ----> 2 raw_image = Image.open(requests.get(img_url, stream=True).raw).convert('RGB')
#       3 display(raw_image.resize((596, 437)))
#
# NameError: name 'Image' is not defined

# %%
device = torch.device("cuda") if torch.cuda.is_available() else "cpu"

# %%
# we associate a model with its preprocessors to make it easier for inference.
model, vis_processors, _ = load_model_and_preprocess(
    name="blip2_t5", model_type="pretrain_flant5xxl", is_eval=True, device=device
)

# Other available models:
# 
# model, vis_processors, _ = load_model_and_preprocess(
#     name="blip2_opt", model_type="pretrain_opt2.7b", is_eval=True, device=device
# )
# model, vis_processors, _ = load_model_and_preprocess(
#     name="blip2_opt", model_type="pretrain_opt6.7b", is_eval=True, device=device
# )
# model, vis_processors, _ = load_model_and_preprocess(
#     name="blip2_opt", model_type="caption_coco_opt2.7b", is_eval=True, device=device
# )
# model, vis_processors, _ = load_model_and_preprocess(
#     name="blip2_opt", model_type="caption_coco_opt6.7b", is_eval=True, device=device
# )
#
# model, vis_processors, _ = load_model_and_preprocess(
#     name="blip2_t5", model_type="pretrain_flant5xl", is_eval=True, device=device
# )
#
# model, vis_processors, _ = load_model_and_preprocess(
#     name="blip2_t5", model_type="caption_coco_flant5xl", is_eval=True, device=device
# )

vis_processors.keys()
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/674 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/9.60G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/10.0G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/6.06G [00:00<?, ?B/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/9.45G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/9.96G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413M/413M [08:10<00:00, 884kB/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # we associate a model with its preprocessors to make it easier for inference.
# ----> 2 model, vis_processors, _ = load_model_and_preprocess(
#       3     name="blip2_t5", model_type="pretrain_flant5xxl", is_eval=True, device=device
#       4 )
#       6 # Other available models:
#       7 #
#       8 # model, vis_processors, _ = load_model_and_preprocess(
#    (...)
#      26 #     name="blip2_t5", model_type="caption_coco_flant5xl", is_eval=True, device=device
#      27 # )
#      29 vis_processors.keys()
#
# File ~/.local/lib/python3.10/site-packages/lavis/models/__init__.py:198, in load_model_and_preprocess(name, model_type, is_eval, device)
#
# File ~/.local/lib/python3.10/site-packages/omegaconf/omegaconf.py:189, in OmegaConf.load(file_)
#     186 from ._utils import get_yaml_loader
#     188 if isinstance(file_, (str, pathlib.Path)):
# --> 189     with io.open(os.path.abspath(file_), "r", encoding="utf-8") as f:
#     190         obj = yaml.load(f, Loader=get_yaml_loader())
#     191 elif getattr(file_, "read", None):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jayn2u/.local/lib/python3.10/site-packages/lavis/configs/models/blip2/blip2_pretrain_flant5xxl.yaml'

# %%
image = vis_processors["eval"](raw_image).unsqueeze(0).to(device)

# %%
model.generate({"image": image})
